# %%
class Node:
    def __init__(self, data, next=None):
        self.head = head
        self.next = next

# %%
class LinkedList:
    def __init__(self, head):
        self.head = head

    def insertNode(self, )
