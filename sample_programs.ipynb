# %% [markdown]
# ### Constraints
# #### 01-06 to 30-09 = kharif
# #### 01-10 to 31-03 = Rabi
# #### 01-02 to 31-05 = summer

# %%
import time

# %%
class Solution:
    def getWeekTimeStamps(self, year):
        kharifStartDate =

# %%
obj=Solution()
obj.getWeekTimeStamps(year)

# %%
round(time.time() * 1000)
# Out:
# 1748886730874
